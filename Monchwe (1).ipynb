# %% [markdown]
# # Mfundo Monchwe
# ## NLSO841
# ### Assignment 3
# ##### 06 july 2021

# %% [markdown]
# ## Question 1
#  ### a.Image restoration problem
#
#   ###   Classification based Data mining Technique in Diabetes care
#   ### Logistic regression
#
#   1.b
#   ### Image restoration problem
#
# To solve large- scale unconstrained optimization problems, a modified conjugae gradient algorithm is proposed found to be interesting because it combines the steepest descent algorithm with the conjugate gradient method and fully utilizes their excellent proprties.
#
#
# the concerned problem is given by:
#
# $\min ({{f(x) | x \in R^n}}),$
#
# where the function
# $ f : R^n -> R$     $and f \in C^2 $
#
# it is well known  that many modern applications of optimization call for studying large scale non-smooth convex optimization problems, where image restoration problem arising  in image processing.
#
# The image restoration problem plays an important role in bio engineering, data science and other areas.
#
# the most common image degradation model is defined by the following system
#
# $ b = Ax + \eta$,
#
# where $x \in R^n $ is the underlying images, $b \in R^m$ is the observed images, A is an $m * n$ blurring matrix and $\eta \in R^m$ denotes the noise.
# one way to get the unknown $\eta$ is to solving the problem  $\min_{x \in R^n} ||Ax+b||^2$ .
#
# this problem will not have a satisfactory solution since the system is very sensitive to lack of information and the noise. the regularized least square problem is often used to overcome the shortcoming
#
# $\min\limits_{x \in R^n} ||AX+b||^2 + \lambda ||D_x||_1,$
#
# where $||.||_1$ is the $l^1$ norm $\lambda$ is the regularization parameter controlling the trade-off between the regularization term and the data-fitting term, and $D$ is linear operator.
#
# ## ii. Classification based Data mining Technique in Diabetes care
#
# the article used Support Vector Machine,
# A support vector machine (SVM) is a machine learning algorithm that looks at  data and sorts it into one of two categories.
# SVM is a supervised and linear Machine Learning algorithm mostly comonly used for solving classification problems abd is also referred to as SUpport Vector Classification. there's also a subset of SVM called Support Vector Regression uses the same principles to solove regression problems.
#
#
# So initially, we are given the data which is to  be separated by the algorithm.
#
# the data given for separating/ classifying is represented as unique point in a space where each point is represented by some feature vector x.
# $x \in R^D$
# $R^D$ is a space vector with $D$ dimension, it isn't necessary to have a hang of this concept for this algorithm.
#
#
# the goal is to maximize the minimum distance
#
# $w^{*} = \arg_{w} max [min_{n} d_{H}(\phi(x_{n}))]$
#
# while making the predictions on the training data which were binary classified as positive and negative groups, if the point is substituted from the postive group in the hyperplane equation, we get a greater then 0 mathematically,
#
# $w^{T}(\phi(x)) + b >0 $
# and predictions, from the negative group in the hyperplain equation would give negative value as
#
# $w^{T}(\phi(x)) + b <0 $
#
# signs given here are about training data, which is how we are training our model. for positive class, given a positive sign and for negative class give a negative sign.
#
# ###iii. Logistic regression
# Logistic regression uses a sigmoid fucntion to estimat the output tha returns a value from 0 to 1, as this is s a binary classification, the output should be either0 or 1.
#
#  LR classified is defined as
#
# $\sigma (f(x_i)) =\Bigg\{^{\geq 0.5 y_i = +1} _{< 0.5 y_i = -1} $
#
# where $\sigma(f(x)) = \frac{1}{1+e^-f(x)} $
#
#
# $\sigma(f(z)) = \frac{1}{1+e^-f(z)} $
#
# * As $z$ ranges from -$\infty$ to $\infty$, $\sigma(z)$ goes from 0 to 1, 'squashing function'
# * it has a 'sigmoid' shape (i.e s-like shape)
#
# Learning is formulated as the optimization problem
#
# $\min\limits_{w\in R^d} \sum_{i}^{N}\log(1+ e^{-y_i f(x_i)}) + \lambda\|w\|^2$
#
# * for correctly classified points $ -y_if(x_i)$ is negative  and $\log(1+e^{-y_i f(x_i)})$ is near zero
# * for incorrectly classified points $-y_if(x_i)$ is positive, and $\log(1+e^{-y_i f(x_i)})$ can be large.
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# c.
#  ## Image restoration problem algorithm:
#
# Step 1:(Initiation) Choose an initial point $x_0, \gamma \in (0,1), \xi_2, \xi_3, and\xi_4>0$ and poitive constants
# $\varepsilon \in (0,1).$
# Let $ k = 0, d_0 = - \nabla \theta^{M}(x_{0})$
#
# Step 2: If $\|\nabla \theta^{M}(x_{k})\| \leq \varepsilon$, then stop.
#
# Step 3: Find the step length, i.e, the calculation
# $\alpha_{k} = \max \{\gamma^{k}\mid k=0,1,2, \ldots \} $ stemming from
#
# $\begin{aligned} \theta ^{M}(x_{k}+\alpha _{k}d_{k}) \leq& \theta ^{M}(x_{k})+ \lambda \alpha _{k}\nabla \theta ^{M}(x_{k})^{T}d_{k} \\ &{}+ \alpha _{k}\min \bigl[-\lambda _{1}\nabla \theta ^{M}(x_{k})^{T}d_{k}, \lambda \alpha _{k}d_{k}^{T}d _{k}/2 \bigr], \end{aligned}$
#
# step 4: Set the new iteration point  $x_{k+1} = x_{k} + \alpha_{k}d_{k}$
#
# step 5: update search direction by
# where $s_{k} = x_{k+1} - x_{k},$
#
# $y_{k} = \nabla \theta^{M} (x_{k+1}) - \nabla \theta ^{M} (x_{k})$, and $ \xi_2,\xi_3 and \xi_4$ are postive constants.
#
# step 6: if $\|\nabla \theta ^{M}(x_{k+1})\|\leq \varepsilon$ holds, the algorithm stops, otherwise goto the next step.
#
# step 7: Let $k := k+1$ and goto step 3.
#
# Algorithm characteristics
# Thid section states the properties of sufficient descent, trust region as global convergence of Algorithm
#
# ##ii. Classification based Data mining Technique in Diabetes care
#
# Algorithm for classification technique
# is SVM
# where we apply similar concept of the domain, range, mapping a function for the data points here, instead of real space, we have a vector space for x.
# ![image.png](data:image/png;base64,...)
#
# further, mapping the point on a complex feature space x,
# $\phi(x) \in R^m$
# the transformed feature space for each input mappedto a trasnformed basis vector $\phi(x)$ can be defined as:
#
# $\phi (x) : R^D <-> R^M$
#
# the product of a predicted and actual label eould be greater than 0 on correc prediction, otherwise less thsan zero.
#
#
# $y_{n}[w^T\phi(X) + b] = \bigg\{ ^{\geq 0 if correct} _{< 0 if incorrect}$
#
# $y_i(w^Tx_i - b) \leq 1,$
# we can put this together to get the optimization problem:
#  $min ||w||$
#  subject to $y_i(w^Tx_i-b) \geq 1$
#
#  for $ i = 1,...,n$
#
#
#
# ###Logistic regression
#  logistic regression utilizes a cost function called cross entropy
#  ![image.png](data:image/png;base64,...)
#
#  ![image.png](data:image/png;base64,...)
#
#  ![image.png](data:image/png;base64,...)
#  ![image.png](data:image/png;base64,...)
#
#
#
#
#  d.Two possible drawbacks for eacg of the algorithms aligned with the problem aplied to solve
#
#  ##Image restoration problem
#
#
#  The fundamental limitation of conjugate gradient method is that it requires, in generanl number of cycles it needs to reach the minimum.
#
#  ##Classification based data mining techique in diabetes care
#
#  SVM algorithm is not suitable for large dataset, SVM does not perform very well when the dataset has too much noise, i.e., target classes overlapping.
#  if the number of features exceed the training samples, the SVM will underperfom
#
#
#  ##Logistic regression
#
#
# * frequent updates are computationally expensive due o the utulizationof all resources for processing one training sample at a time.
# * due to frequent updates, steps taken foreard to minima are heavily noisy. th can often lead thegradient deescent into other directions.
#
# e.
# #conjugate gradient method
#
#
# * a procedure is needed which will perform most of the fucntion in first few cycles to assist in the limitation of cycles.
#
# ##classification based data mining technique in diaabetes care
#
# * SVM should be mainly focused used on small datasets to avoid the issue of overfitting.
# * number of features must be less than number of training samples to avoid the SVM model underpeform in the dataset.
#
# ## logistic regression
#
#
# to overdrawvCK GRADIENT DESCENT BEING SLOW, STOCHASTIC GRADIENT ALGORITHM CAN IMPLEENTED AS AN SUBSTITUTE.
# * use cost function minimization.

# %% [markdown]
# # Question 2
# a. Algorithms
#
# i. Conjugate gradient method
#
# $x_0$ $\in$ $R^n$
#
# $r_0 = Ax_0 -b,$
#
# $p_0 = -r_0,$
#
# $k = 0$
#
# $ while$      $r_k $  $\neq$     $do$
#
#  $ d_k $ = -$\frac{ r^T _k p_k} {p_k Ap_k} ;$
#
#  $x_{K+1}$   =  $x_k$ + $\alpha_k P_k ;$
#
#  $r_{k+1} = Ax_k+1 - b;$
#
#  $\beta_{k+1} = \frac{r^T _{k+1} Ap_k} {p^T_k Ap_k} ;$
#
#  $p_{k+1} = - r_{k+1} + \beta_k P_k;$
#
#  $ k = k+1;$
#
#  $end while$
#
#  $\alpha_k = - \frac{r^T _k r_k}{p^T _k Ap_k};$
#
#  $\beta_{k+1} = \frac{r^T_{k+1} r_{k+1}} {r^T_k r_k};$
#
#  ii.  Accelerated gradient descent
#
# $x_{k+1} = y_k - \epsilon \nabla f(y_k)$
#
# $y_k = x_k - \frac{k-1}{k+2} (x_k -x_{k-1})$
#
# iii. Randomized coordinate gradient descent
#
# $Input: x_0 \in R^n $ //starting point
#
# $Output: x$
#
# $ set x: x_0$
#
# $for k := 1, 2,.... do$
#
# choose coordinate i $\in$ ${1,2,...n}$, uniformly at random
#
# update $ x^(i) = x^(i) - \frac{1} {L_i} \nabla_i f(x) $
#
# **end for**
#
# iv. Stochastic gradient descent algorithm
#
# $Input : x_1 \in C, positive sequence $
#
#
# for   $s = 1 $ to $k-1 do$
#
# $y_{s+1} = x_s - \eta_sg_s$
#
# $x_{s+1} = \pi_c(y_{s+1}) $
#
# end for
#
# return $$ x_k = \frac{1}{k} \sum_{s=1}^{k}  x_s$$
#
# b. Describe and provide mathematical model
#
# i. Linear regression: a linear approach to modelling the relation between feature variables $(x^{i} _ j)$ and target variable $(y^{i})$. in linear regression, the relationships are modeled using linear predictor functions whose unknown model parameters are estimated from the data given.
# * if the goal is prediction, forecasting or error reduction, linear regression can be implemented to fit a predictve model to an observed dataset of values of the response and explanatory variables. the fitted model can be used to make predictions based on selected features.
#
# * if the goal is to explain variation in response variable that can be analysis to variation in the feature variables, analyses of linear regression can be applied to quantify the strength of the relationship between target variable and feature variables.
#
# Mathematical model
#
# $y_i = \beta_0 + \beta_1x_i +......+  \beta_pxi + \epsilon_i  =  x^T _i \beta + \epsilon_i $
#
# ii. Logistic regression:
#
# Logistic regression is actually a classification.
# * LR introduces an extra non-linearity over a linear classifier, $f(x) = w^T x + b$, by using a logistic (or sigmoid ) function , $\sigma()$.
#
# * LR classified is defined as
#
# $\sigma (f(x_i)) =\Bigg\{^{\geq 0.5 y_i = +1} _{< 0.5 y_i = -1} $
#
# where $\sigma(f(x)) = \frac{1}{1+e^-f(x)} $
#
#
# $\sigma(f(z)) = \frac{1}{1+e^-f(z)} $
#
# * As $z$ ranges from -$\infty$ to $\infty$, $\sigma(z)$ goes from 0 to 1, 'squashing function'
# * it has a 'sigmoid' shape (i.e s-like shape)
#
# Learning is formulated as the optimization problem
#
# $\min\limits_{w\in R^d} \sum_{i}^{N}\log(1+ e^{-y_i f(x_i)}) + \lambda\|w\|^2$
#
# * for correctly classified points $ -y_if(x_i)$ is negative  and $\log(1+e^{-y_i f(x_i)})$ is near zero
# * for incorrectly classified points $-y_if(x_i)$ is positive, and $\log(1+e^{-y_i f(x_i)})$ can be large.
#
# * hence the optimization penalizes parameters which to such misclassifications.
#
# c. LASSO stands for Least Absolute Shrinkage and Selection Operator.
# it is a statistical formula for regularisation of data models an feature selection.
#
# Regularization is a vital concept that is implemented to avoid overfitting of data, mostly when trained and test data are very much varying.
# Regularization is implemented by  adding 'penalty; term, to the best fit derived from the trained data, to achieve a lesser variance with the tested data and also restricts the influence of predictor variavles over the output variable by compressing their coeffiecients.
#
# Lasso regresiion is a regularization technque, which is used over regression methods for more accurate prediction. this model uses shrinkage. shrinkage is where data values are shrunk towards a central point as the mean. the lasso procedure encourafes models with fewer parameters. this is particular type of regression is best fitted for models with high leves of multicolinearitym like variable selection/parameter elimination.
#
# #Mathematical equation of Lasso Regression
# ##Residual Sum of Squares + $\lambda$ *(sum of the absolute value of the magnitude of coefficients)
#
#
# $$\sum_{i=1}^n \big(y_i - \sum_{j} x_ij\beta_j)^2 + \sum_{j=1}^p |\beta_j|$$
#
#
#
# where
# * $\lambda$ denotes the amount of shrinkage
# * $\lambda = 0$ implies all features are considered and it is equivalent to the linear regression where only the residua l sum of squares is considered to build a predictive model
# * $\lambda = \infty $ implies no feature is considered
# * bias increases with increase in $\lambda$
# * variance increases with decrease in $\lambda$

# %% [markdown]
# #References
# ##Given below are the references that I used for my entire assignment in no particular order
#
#
#
# 1.   En.wikipedia.org. 2021. Linear regression - Wikipedia. [online] Available at: <https://en.wikipedia.org/wiki/Linear_regression> [Accessed 7 July 2021].
# 2.   Cs.toronto.edu. 2021. [online] Available at: <https://www.cs.toronto.edu/~rgrosse/courses/csc311_f20/readings/notes_on_linear_regression.pdf> [Accessed 7 July 2021].
# 3. Sebastian Ruder. 2021. An overview of gradient descent optimization algorithms. [online] Available at: <https://ruder.io/optimizing-gradient-descent/index.html#nesterovacceleratedgradient> [Accessed 7 July 2021].
# 4. Ocw.mit.edu. 2021. [online] Available at: <https://ocw.mit.edu/courses/mathematics/18-657-mathematics-of-machine-learning-fall-2015/lecture-notes/MIT18_657F15_L14.pdf> [Accessed 7 July 2021].
# 5. GreatLearning Blog: Free Resources what Matters to shape your Career!. 2021. What is LASSO Regression Definition, Examples and Techniques. [online] Available at: <https://www.mygreatlearning.com/blog/understanding-of-lasso-regression/> [Accessed 7 July 2021].
# 6. Yuan, G., Li, T. and Hu, W., 2019. A conjugate gradient algorithm and its application in large-scale optimization problems and image restoration. Journal of Inequalities and Applications, 2019(1).
# 7. code), U., 2021. SVM | Support Vector Machine Algorithm in Machine Learning. [online] Analytics Vidhya. Available at: <https://www.analyticsvidhya.com/blog/2017/09/understaing-support-vector-machine-example-code/> [Accessed 7 July 2021].
# 8. En.wikipedia.org. 2021. Support-vector machine - Wikipedia. [online] Available at: <https://en.wikipedia.org/wiki/Support_vector_machine> [Accessed 7 July 2021].
# 9. Science Alert. 2021. Application of Classification based Data Mining Technique in Diabetes Care. [online] Available at: <https://scialert.net/fulltext/?doi=jas.2013.416.422> [Accessed 7 July 2021].
# 10. https://ml-cheatsheet.readthedocs.io/en/latest/logistic_regression.html#cost-function
# 11. https://sdsclub.com/stochastic-gradient-descent-vs-gradient-descent-a-head-to-head-comparison/
# 12. Asquero (2020) ‘Advantages and Disadvantages of stochastic Gradient Descent’, Asquero. Available at: https://www.asquero.com/article/advantages-and-disadvantages-of-stochastic-gradient-descent/ (Accessed: 04 June 2021)
# 13. Stack Exchange (2014) ‘What are alternatives of Gradient Descent’, Stack Exchange. Available at: https://stats.stackexchange.com/questions/97014/what-are-alternatives-of-gradient-descent (Accessed: 04 June 2021)
